# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

link = "https://raw.githubusercontent.com/murpi/wilddata/master/quests/cars.csv"
df_cars = pd.read_csv(link)

df_cars.head()
# Out:
#     mpg  cylinders  cubicinches   hp  weightlbs  time-to-60  year continent
# 0  14.0          8          350  165       4209          12  1972       US.
# 1  31.9          4           89   71       1925          14  1980   Europe.
# 2  17.0          8          302  140       3449          11  1971       US.
# 3  15.0          8          400  150       3761          10  1971       US.
# 4  30.5          4           98   63       2051          17  1978       US.

# %%
df_cars.dropna()
# Out:
#       mpg  cylinders  cubicinches   hp  weightlbs  time-to-60  year continent
# 0    14.0          8          350  165       4209          12  1972       US.
# 1    31.9          4           89   71       1925          14  1980   Europe.
# 2    17.0          8          302  140       3449          11  1971       US.
# 3    15.0          8          400  150       3761          10  1971       US.
# 4    30.5          4           98   63       2051          17  1978       US.
# ..    ...        ...          ...  ...        ...         ...   ...       ...
# 256  17.0          8          305  130       3840          15  1980       US.
# 257  36.1          4           91   60       1800          16  1979    Japan.
# 258  22.0          6          232  112       2835          15  1983       US.
# 259  18.0          6          232  100       3288          16  1972       US.
# 260  22.0          6          250  105       3353          15  1977       US.
#
# [261 rows x 8 columns]

# %%
df_cars['continent'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 261 entries, 0 to 260
# Series name: continent
# Non-Null Count  Dtype
# --------------  -----
# 261 non-null    object
# dtypes: object(1)
# memory usage: 2.2+ KB

# %%
df_cars['continent'].unique()
# Out:
# array([' US.', ' Europe.', ' Japan.'], dtype=object)

# %%
#print (df_cars[pd.to_numeric(df_cars['continent'], errors='coerce').isnull()])

# %%
df_continent = pd.get_dummies(df_cars["continent"],dtype='int')
df_continent
# Out:
#       Europe.   Japan.   US.
# 0           0        0     1
# 1           1        0     0
# 2           0        0     1
# 3           0        0     1
# 4           0        0     1
# ..        ...      ...   ...
# 256         0        0     1
# 257         0        1     0
# 258         0        0     1
# 259         0        0     1
# 260         0        0     1
#
# [261 rows x 3 columns]

# %%
df_cars2 = pd.concat([df_cars, df_continent], axis=1)
df_cars2
# Out:
#       mpg  cylinders  cubicinches   hp  weightlbs  time-to-60  year continent  \
# 0    14.0          8          350  165       4209          12  1972       US.
# 1    31.9          4           89   71       1925          14  1980   Europe.
# 2    17.0          8          302  140       3449          11  1971       US.
# 3    15.0          8          400  150       3761          10  1971       US.
# 4    30.5          4           98   63       2051          17  1978       US.
# ..    ...        ...          ...  ...        ...         ...   ...       ...
# 256  17.0          8          305  130       3840          15  1980       US.
# 257  36.1          4           91   60       1800          16  1979    Japan.
# 258  22.0          6          232  112       2835          15  1983       US.
# 259  18.0          6          232  100       3288          16  1972       US.
# 260  22.0          6          250  105       3353          15  1977       US.
#
#       Europe.   Japan.   US.
# ...

# %%
# Create a copy of df_cars2 with the 'Continent' column
df_cars3 = df_cars2.copy()

# Drop the 'Continent' column in df_cars3
df_cars3.drop('continent', axis=1, inplace=True)

# %%
df_cars2
# Out:
#       mpg  cylinders  cubicinches   hp  weightlbs  time-to-60  year continent  \
# 0    14.0          8          350  165       4209          12  1972       US.
# 1    31.9          4           89   71       1925          14  1980   Europe.
# 2    17.0          8          302  140       3449          11  1971       US.
# 3    15.0          8          400  150       3761          10  1971       US.
# 4    30.5          4           98   63       2051          17  1978       US.
# ..    ...        ...          ...  ...        ...         ...   ...       ...
# 256  17.0          8          305  130       3840          15  1980       US.
# 257  36.1          4           91   60       1800          16  1979    Japan.
# 258  22.0          6          232  112       2835          15  1983       US.
# 259  18.0          6          232  100       3288          16  1972       US.
# 260  22.0          6          250  105       3353          15  1977       US.
#
#       Europe.   Japan.   US.
# ...

# %%
df_cars3
# Out:
#       mpg  cylinders  cubicinches   hp  weightlbs  time-to-60  year   Europe.  \
# 0    14.0          8          350  165       4209          12  1972         0
# 1    31.9          4           89   71       1925          14  1980         1
# 2    17.0          8          302  140       3449          11  1971         0
# 3    15.0          8          400  150       3761          10  1971         0
# 4    30.5          4           98   63       2051          17  1978         0
# ..    ...        ...          ...  ...        ...         ...   ...       ...
# 256  17.0          8          305  130       3840          15  1980         0
# 257  36.1          4           91   60       1800          16  1979         0
# 258  22.0          6          232  112       2835          15  1983         0
# 259  18.0          6          232  100       3288          16  1972         0
# 260  22.0          6          250  105       3353          15  1977         0
#
#       Japan.   US.
# ...

# %%
corr = df_cars2.corr()
sns.heatmap(corr, cmap = 'RdBu', center=0, annot=True)
plt.show()
# mpg : miles per gallon donc consommation de carburant, plus cette cote est elevée mieux c'est.
# cubicinches : if your engine has a higher number of cubic inches, that would equate to your engine burning a greater volume of air and fuel mixture. That would typically mean your engine produces more power. 
# hp : horse power : the higher the better
# time to 60 : The time it takes a vehicle to accelerate from 0 to 60 miles per hour


# correlation positive forte entre les cubicinches et les cylinders, entre weightlbs et les cubicsinches , hp et cubicinches 
# correlation positive entre year et mpg , time to 60 and mpg
# correlation
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[159], line 1
# ----> 1 corr = df_cars2.corr()
#       2 sns.heatmap(corr, cmap = 'RdBu', center=0, annot=True)
#       3 plt.show()
#
# File c:\Users\Margaux\anaconda3\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\Margaux\anaconda3\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
# ...

# %%
df_sample = df_cars2.sample(n=20, random_state=10)
sns.pairplot(df_sample)
plt.show()
# Out:
# c:\Users\Margaux\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
import math
num_columns = len(df_cars2.columns)
num_rows = math.ceil(num_columns / 3)
plt.figure(figsize=(15, 5 * num_rows))

for i, column in enumerate(df_cars2.columns, 1):
    plt.subplot(num_rows, 3, i)
    sns.histplot(df_cars2[column], kde=True)
    plt.title(f'Distribution de {column}')
    plt.xlabel(column)
    plt.ylabel('Fréquence')
plt.tight_layout()
plt.show()

# %%
# Créer une distribution avec Seaborn
sns.set(style="whitegrid")  # Configuration du style de la grille

# Utiliser la fonction distplot pour créer la distribution
sns.distplot(df_cars2['mpg'], kde=False, bins=20, color='skyblue')

# Ajouter des labels et un titre
plt.xlabel('Miles per Gallon (mpg)')
plt.title('Distribution of Miles per Gallon')

# Afficher le graphique
plt.show()
# Out:
# C:\Users\Margaux\AppData\Local\Temp\ipykernel_17260\4212351389.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_cars2['mpg'], kde=False, bins=20, color='skyblue')
