# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import plotly.express as px

link = "https://raw.githubusercontent.com/murpi/wilddata/master/quests/cars.csv"
df_cars = pd.read_csv(link)

df_cars.head()
# Out:
#     mpg  cylinders  cubicinches   hp  weightlbs  time-to-60  year continent
# 0  14.0          8          350  165       4209          12  1972       US.
# 1  31.9          4           89   71       1925          14  1980   Europe.
# 2  17.0          8          302  140       3449          11  1971       US.
# 3  15.0          8          400  150       3761          10  1971       US.
# 4  30.5          4           98   63       2051          17  1978       US.

# %%
us =df_cars['continent'].unique()
us
# Out:
# array([' US.', ' Europe.', ' Japan.'], dtype=object)

# %%
filtered_df = df_cars[df_cars['continent'].isin(country)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 filtered_df = df_cars[df_cars['continent'].isin(country)]
#
# NameError: name 'country' is not defined

# %%
regions = df_cars['continent'].unique()

# Filtrage par région
df_filtered = df_cars[df_cars['continent'] == selected_region]

# Affichage du nombre de lignes après filtrage
st.sidebar.markdown(f"Nombre de lignes pour la région {selected_region}: {len(df_filtered)}")

# %%
import plotly.express as px

# Supprimer la colonne 'continent'
df_without_continent = df_cars.drop('continent', axis=1)

# Créer la heatmap avec Plotly Express
fig = px.imshow(df_without_continent.corr(), labels=dict(color='Corrélation'), x=df_without_continent.columns, y=df_without_continent.columns)
fig.update_layout(title='Heatmap de Corrélation (sans la colonne "continent")', width=800, height=600)

# Afficher la heatmap
fig.show()

# %%
# Supprimer la colonne 'continent'
df_without_continent = df_cars.drop('continent', axis=1)

# Créer la heatmap
plt.figure(figsize=(10, 8))
heatmap = sns.heatmap(df_without_continent.corr(), annot=True, cmap='coolwarm')

# Afficher la heatmap
plt.show()

# %%
import math
num_columns = len(df_cars.columns)
num_rows = math.ceil(num_columns / 3)
plt.figure(figsize=(15, 5 * num_rows))

for i, column in enumerate(df_cars.columns, 1):
    plt.subplot(num_rows, 3, i)
    sns.histplot(df_cars[column], kde=True)
    plt.title(f'Distribution de {column}')
    plt.xlabel(column)
    plt.ylabel('Fréquence')
plt.tight_layout()
plt.show()

# %%
df_cars
# Out:
#       mpg  cylinders  cubicinches   hp  weightlbs  time-to-60  year  continent
# 0    14.0          8          350  165       4209          12  1972        NaN
# 1    31.9          4           89   71       1925          14  1980        NaN
# 2    17.0          8          302  140       3449          11  1971        NaN
# 3    15.0          8          400  150       3761          10  1971        NaN
# 4    30.5          4           98   63       2051          17  1978        NaN
# ..    ...        ...          ...  ...        ...         ...   ...        ...
# 256  17.0          8          305  130       3840          15  1980        NaN
# 257  36.1          4           91   60       1800          16  1979        NaN
# 258  22.0          6          232  112       2835          15  1983        NaN
# 259  18.0          6          232  100       3288          16  1972        NaN
# 260  22.0          6          250  105       3353          15  1977        NaN
#
# [261 rows x 8 columns]

# %%
df_japan = df_cars[df_cars['continent'] == ''].sort_values(by='US')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17260\253054562.py in ?()
# ----> 1 df_japan = df_cars[df_cars['continent'] == ''].sort_values(by='US')
#
# c:\Users\Margaux\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6754         elif len(by):
#    6755             # len(by) == 1
#    6756
#    6757             by = by[0]
# -> 6758             k = self._get_label_or_level_values(by, axis=axis)
#    6759
#    6760             # need to rewrap column in Series to apply key function
#    6761             if key is not None:
#
# c:\Users\Margaux\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1774             values = self.xs(key, axis=other_axes[0])._values
#    1775         elif self._is_level_reference(key, axis=axis):
# ...
